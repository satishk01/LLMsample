# %%
# !pip install torch
# !pip install playwright==1.25
# !pip install transformers
# !pip install packaging
# !pip install ninja
# !pip install spaces
# !pip install flash_attn einops
# !pip install einops flash_attn
# !pip install gradio
# Out:
# Requirement already satisfied: torch in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (2.1.0)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch) (4.9.0)
# Requirement already satisfied: sympy in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Collecting playwright==1.25
#   Downloading playwright-1.25.0-py3-none-manylinux1_x86_64.whl.metadata (3.4 kB)
# Collecting websockets==10.1 (from playwright==1.25)
#   Downloading websockets-10.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.3 kB)
# Collecting greenlet==1.1.2 (from playwright==1.25)
#   Downloading greenlet-1.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting pyee==8.1.0 (from playwright==1.25)
#   Downloading pyee-8.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading playwright-1.25.0-py3-none-manylinux1_x86_64.whl (32.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 18.4 MB/s eta 0:00:0000:0100:01m
# Downloading greenlet-1.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (155 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.4/155.4 kB 28.5 MB/s eta 0:00:00
# Downloading pyee-8.1.0-py2.py3-none-any.whl (12 kB)
# Downloading websockets-10.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (110 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 2.3 MB/s eta 0:00:00ta 0:00:01
# Installing collected packages: pyee, websockets, greenlet, playwright
# Successfully installed greenlet-1.1.2 playwright-1.25.0 pyee-8.1.0 websockets-10.1
# Collecting transformers
#   Downloading transformers-4.40.1-py3-none-any.whl.metadata (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.0/138.0 kB 15.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from transformers) (3.13.1)
# Collecting huggingface-hub<1.0,>=0.19.3 (from transformers)
#   Downloading huggingface_hub-0.22.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.17 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from transformers) (6.0.1)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading regex-2024.4.16-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.20,>=0.19 (from transformers)
#   Downloading tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.4.1 (from transformers)
#   Downloading safetensors-0.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: tqdm>=4.27 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2024.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from requests->transformers) (2024.2.2)
# Downloading transformers-4.40.1-py3-none-any.whl (9.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 56.7 MB/s eta 0:00:00:00:0100:01
# Downloading huggingface_hub-0.22.2-py3-none-any.whl (388 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.9/388.9 kB 49.9 MB/s eta 0:00:00
# Downloading regex-2024.4.16-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (773 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 774.0/774.0 kB 80.2 MB/s eta 0:00:00
# Downloading safetensors-0.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 96.5 MB/s eta 0:00:00
# Downloading tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 146.1 MB/s eta 0:00:00
# Installing collected packages: safetensors, regex, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.22.2 regex-2024.4.16 safetensors-0.4.3 tokenizers-0.19.1 transformers-4.40.1
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from packaging) (3.1.1)
# Collecting ninja
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl.metadata (5.3 kB)
# Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 5.0 MB/s eta 0:00:00ta 0:00:01
# Installing collected packages: ninja
# Successfully installed ninja-1.11.1.1
# Collecting spaces
#   Downloading spaces-0.26.1-py3-none-any.whl.metadata (997 bytes)
# Collecting gradio (from spaces)
#   Downloading gradio-4.27.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: httpx>=0.20 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from spaces) (0.27.0)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from spaces) (21.3)
# Requirement already satisfied: psutil<6,>=2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from spaces) (5.9.8)
# Requirement already satisfied: pydantic<3,>=1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from spaces) (2.6.1)
# Requirement already satisfied: requests<3.0,>=2.19 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from spaces) (2.31.0)
# Requirement already satisfied: typing-extensions<5,>=4 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from spaces) (4.9.0)
# Requirement already satisfied: anyio in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from httpx>=0.20->spaces) (4.3.0)
# Requirement already satisfied: certifi in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from httpx>=0.20->spaces) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from httpx>=0.20->spaces) (1.0.4)
# Requirement already satisfied: idna in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from httpx>=0.20->spaces) (3.6)
# Requirement already satisfied: sniffio in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from httpx>=0.20->spaces) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.20->spaces) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from pydantic<3,>=1->spaces) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from pydantic<3,>=1->spaces) (2.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from requests<3.0,>=2.19->spaces) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from requests<3.0,>=2.19->spaces) (2.0.7)
# Collecting aiofiles<24.0,>=22.0 (from gradio->spaces)
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Collecting altair<6.0,>=4.2.0 (from gradio->spaces)
#   Downloading altair-5.3.0-py3-none-any.whl.metadata (9.2 kB)
# Collecting fastapi (from gradio->spaces)
#   Downloading fastapi-0.110.2-py3-none-any.whl.metadata (24 kB)
# Collecting ffmpy (from gradio->spaces)
#   Downloading ffmpy-0.3.2.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gradio-client==0.15.1 (from gradio->spaces)
#   Downloading gradio_client-0.15.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio->spaces) (0.22.2)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio->spaces) (6.1.1)
# Requirement already satisfied: jinja2<4.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio->spaces) (3.1.3)
# Requirement already satisfied: markupsafe~=2.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio->spaces) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio->spaces) (3.8.3)
# Requirement already satisfied: numpy~=1.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio->spaces) (1.26.4)
# Collecting orjson~=3.0 (from gradio->spaces)
#   Downloading orjson-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas<3.0,>=1.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio->spaces) (1.5.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio->spaces) (10.2.0)
# Collecting pydub (from gradio->spaces)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-multipart>=0.0.9 (from gradio->spaces)
#   Downloading python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio->spaces) (6.0.1)
# Collecting ruff>=0.2.2 (from gradio->spaces)
#   Downloading ruff-0.4.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (23 kB)
# Collecting semantic-version~=2.0 (from gradio->spaces)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting tomlkit==0.12.0 (from gradio->spaces)
#   Downloading tomlkit-0.12.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting typer<1.0,>=0.12 (from gradio->spaces)
#   Downloading typer-0.12.3-py3-none-any.whl.metadata (15 kB)
# Collecting uvicorn>=0.14.0 (from gradio->spaces)
#   Downloading uvicorn-0.29.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: fsspec in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio-client==0.15.1->gradio->spaces) (2024.2.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio-client==0.15.1->gradio->spaces) (10.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from packaging->spaces) (3.1.1)
# Requirement already satisfied: jsonschema>=3.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from altair<6.0,>=4.2.0->gradio->spaces) (4.21.1)
# Collecting toolz (from altair<6.0,>=4.2.0->gradio->spaces)
#   Downloading toolz-0.12.1-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from huggingface-hub>=0.19.3->gradio->spaces) (3.13.1)
# Requirement already satisfied: tqdm>=4.42.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from huggingface-hub>=0.19.3->gradio->spaces) (4.66.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from matplotlib~=3.0->gradio->spaces) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from matplotlib~=3.0->gradio->spaces) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from matplotlib~=3.0->gradio->spaces) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from matplotlib~=3.0->gradio->spaces) (1.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from matplotlib~=3.0->gradio->spaces) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from pandas<3.0,>=1.0->gradio->spaces) (2024.1)
# Requirement already satisfied: click>=8.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from typer<1.0,>=0.12->gradio->spaces) (8.1.7)
# Collecting shellingham>=1.3.0 (from typer<1.0,>=0.12->gradio->spaces)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer<1.0,>=0.12->gradio->spaces)
#   Downloading rich-13.7.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from anyio->httpx>=0.20->spaces) (1.2.0)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi->gradio->spaces)
#   Downloading starlette-0.37.2-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: attrs>=22.2.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->spaces) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->spaces) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->spaces) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio->spaces) (0.18.0)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio->spaces) (1.16.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<1.0,>=0.12->gradio->spaces)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio->spaces) (2.17.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio->spaces)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading spaces-0.26.1-py3-none-any.whl (18 kB)
# Downloading gradio-4.27.0-py3-none-any.whl (17.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 50.8 MB/s eta 0:00:00:00:010:01
# Downloading gradio_client-0.15.1-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 7.7 MB/s eta 0:00:00:00:01
# Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading altair-5.3.0-py3-none-any.whl (857 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.8/857.8 kB 12.7 MB/s eta 0:00:0000:01
# Downloading orjson-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 32.3 MB/s eta 0:00:00
# Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Downloading ruff-0.4.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 151.0 MB/s eta 0:00:0000:01
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading typer-0.12.3-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 10.1 MB/s eta 0:00:00
# Downloading uvicorn-0.29.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 14.3 MB/s eta 0:00:00
# Downloading fastapi-0.110.2-py3-none-any.whl (91 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.9/91.9 kB 19.5 MB/s eta 0:00:00
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.7/240.7 kB 6.5 MB/s eta 0:00:00:00:01
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 15.0 MB/s eta 0:00:00
# Downloading toolz-0.12.1-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 10.4 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 2.4 MB/s eta 0:00:00
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: ffmpy
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.2-py3-none-any.whl size=5584 sha256=1bb484610773a22698b2757c4e3afb42e19f9424d08ce16f93fa770d4f8a3981
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/bd/65/9a/671fc6dcde07d4418df0c592f8df512b26d7a0029c2a23dd81
# Successfully built ffmpy
# Installing collected packages: pydub, ffmpy, uvicorn, toolz, tomlkit, shellingham, semantic-version, ruff, python-multipart, orjson, mdurl, aiofiles, starlette, markdown-it-py, rich, gradio-client, fastapi, typer, altair, gradio, spaces
# Successfully installed aiofiles-23.2.1 altair-5.3.0 fastapi-0.110.2 ffmpy-0.3.2 gradio-4.27.0 gradio-client-0.15.1 markdown-it-py-3.0.0 mdurl-0.1.2 orjson-3.10.1 pydub-0.25.1 python-multipart-0.0.9 rich-13.7.1 ruff-0.4.1 semantic-version-2.10.0 shellingham-1.5.4 spaces-0.26.1 starlette-0.37.2 tomlkit-0.12.0 toolz-0.12.1 typer-0.12.3 uvicorn-0.29.0
# Collecting flash_attn
#   Downloading flash_attn-2.5.7.tar.gz (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 39.4 MB/s eta 0:00:00:00:01
#   Preparing metadata (setup.py) ... done
# Collecting einops
#   Downloading einops-0.7.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: torch in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from flash_attn) (2.1.0)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from flash_attn) (21.3)
# Requirement already satisfied: ninja in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from flash_attn) (1.11.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from packaging->flash_attn) (3.1.1)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch->flash_attn) (3.13.1)
# Requirement already satisfied: typing-extensions in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch->flash_attn) (4.9.0)
# Requirement already satisfied: sympy in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch->flash_attn) (1.12)
# Requirement already satisfied: networkx in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch->flash_attn) (3.2.1)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch->flash_attn) (3.1.3)
# Requirement already satisfied: fsspec in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch->flash_attn) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from jinja2->torch->flash_attn) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from sympy->torch->flash_attn) (1.3.0)
# Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 7.7 MB/s eta 0:00:00
# Building wheels for collected packages: flash_attn
#   Building wheel for flash_attn (setup.py) ... done
#   Created wheel for flash_attn: filename=flash_attn-2.5.7-cp310-cp310-linux_x86_64.whl size=120616631 sha256=d3a5f535b169b2969d859ee6bb6d8dabe3b30c687f926da42787683a5f6f15f6
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/13/96/ed/bcac89c56b606421f99b45b16a94db5d0f2b6b4eaf8bac4d01
# Successfully built flash_attn
# Installing collected packages: einops, flash_attn
# Successfully installed einops-0.7.0 flash_attn-2.5.7
# Requirement already satisfied: einops in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (0.7.0)
# Requirement already satisfied: flash_attn in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (2.5.7)
# Requirement already satisfied: torch in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from flash_attn) (2.1.0)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from flash_attn) (21.3)
# Requirement already satisfied: ninja in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from flash_attn) (1.11.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from packaging->flash_attn) (3.1.1)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch->flash_attn) (3.13.1)
# Requirement already satisfied: typing-extensions in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch->flash_attn) (4.9.0)
# Requirement already satisfied: sympy in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch->flash_attn) (1.12)
# Requirement already satisfied: networkx in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch->flash_attn) (3.2.1)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch->flash_attn) (3.1.3)
# Requirement already satisfied: fsspec in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from torch->flash_attn) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from jinja2->torch->flash_attn) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from sympy->torch->flash_attn) (1.3.0)
# Requirement already satisfied: gradio in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (4.27.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio) (5.3.0)
# Requirement already satisfied: fastapi in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio) (0.110.2)
# Requirement already satisfied: ffmpy in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio) (0.3.2)
# Requirement already satisfied: gradio-client==0.15.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio) (0.15.1)
# Requirement already satisfied: httpx>=0.24.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio) (0.22.2)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio) (6.1.1)
# Requirement already satisfied: jinja2<4.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio) (3.1.3)
# Requirement already satisfied: markupsafe~=2.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio) (3.8.3)
# Requirement already satisfied: numpy~=1.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio) (3.10.1)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio) (21.3)
# Requirement already satisfied: pandas<3.0,>=1.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio) (1.5.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio) (10.2.0)
# Requirement already satisfied: pydantic>=2.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio) (2.6.1)
# Requirement already satisfied: pydub in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio) (0.0.9)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio) (6.0.1)
# Requirement already satisfied: ruff>=0.2.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio) (0.4.1)
# Requirement already satisfied: semantic-version~=2.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio) (0.12.3)
# Requirement already satisfied: typing-extensions~=4.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio) (4.9.0)
# Requirement already satisfied: urllib3~=2.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio) (2.0.7)
# Requirement already satisfied: uvicorn>=0.14.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio) (0.29.0)
# Requirement already satisfied: fsspec in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio-client==0.15.1->gradio) (2024.2.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from gradio-client==0.15.1->gradio) (10.1)
# Requirement already satisfied: jsonschema>=3.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from altair<6.0,>=4.2.0->gradio) (4.21.1)
# Requirement already satisfied: toolz in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from altair<6.0,>=4.2.0->gradio) (0.12.1)
# Requirement already satisfied: anyio in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from httpx>=0.24.1->gradio) (4.3.0)
# Requirement already satisfied: certifi in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from httpx>=0.24.1->gradio) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from httpx>=0.24.1->gradio) (1.0.4)
# Requirement already satisfied: idna in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from httpx>=0.24.1->gradio) (3.6)
# Requirement already satisfied: sniffio in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from httpx>=0.24.1->gradio) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.24.1->gradio) (0.14.0)
# Requirement already satisfied: filelock in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from huggingface-hub>=0.19.3->gradio) (3.13.1)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from huggingface-hub>=0.19.3->gradio) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from huggingface-hub>=0.19.3->gradio) (4.66.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from pandas<3.0,>=1.0->gradio) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from pydantic>=2.0->gradio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from pydantic>=2.0->gradio) (2.16.2)
# Requirement already satisfied: click>=8.0.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from typer<1.0,>=0.12->gradio) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from typer<1.0,>=0.12->gradio) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from typer<1.0,>=0.12->gradio) (13.7.1)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from fastapi->gradio) (0.37.2)
# Requirement already satisfied: attrs>=22.2.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.33.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.18.0)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.17.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from anyio->httpx>=0.24.1->gradio) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from requests->huggingface-hub>=0.19.3->gradio) (3.3.2)
# Requirement already satisfied: mdurl~=0.1 in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio) (0.1.2)

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- ---------------
# aiofiles                  23.2.1
# altair                    5.3.0
# aniso8601                 9.0.1
# annotated-types           0.6.0
# ansi2html                 1.9.1
# anyio                     4.3.0
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 2.4.1
# async-lru                 2.0.4
# attrs                     23.2.0
# autovizwidget             0.21.0
# awscli                    1.32.85
# Babel                     2.14.0
# beautifulsoup4            4.12.3
# bleach                    6.1.0
# blinker                   1.7.0
# bokeh                     3.3.4
# boto3                     1.34.85
# botocore                  1.34.85
# Brotli                    1.1.0
# cached-property           1.5.2
# captum                    0.6.0
# certifi                   2024.2.2
# cffi                      1.16.0
# charset-normalizer        3.3.2
# click                     8.1.7
# cloudpickle               2.2.1
# colorama                  0.4.4
# comm                      0.2.1
# contextlib2               21.6.0
# contourpy                 1.2.0
# cryptography              42.0.4
# cycler                    0.12.1
# debugpy                   1.8.1
# decorator                 5.1.1
# defusedxml                0.7.1
# dill                      0.3.8
# docker                    6.1.3
# docutils                  0.16
# dparse                    0.6.3
# einops                    0.7.0
# entrypoints               0.4
# environment-kernels       1.2.0
# exceptiongroup            1.2.0
# executing                 2.0.1
# fastapi                   0.110.2
# fastjsonschema            2.19.1
# ffmpy                     0.3.2
# filelock                  3.13.1
# flash-attn                2.5.7
# Flask                     3.0.2
# Flask-RESTful             0.3.10
# fonttools                 4.49.0
# fqdn                      1.5.1
# fsspec                    2024.2.0
# gmpy2                     2.1.2
# google-pasta              0.2.0
# gradio                    4.27.0
# gradio_client             0.15.1
# greenlet                  1.1.2
# gssapi                    1.8.3
# gym                       0.26.2
# gym-notices               0.0.8
# h11                       0.14.0
# h2                        4.1.0
# hdijupyterutils           0.21.0
# hpack                     4.0.0
# httpcore                  1.0.4
# httpx                     0.27.0
# huggingface-hub           0.22.2
# hyperframe                6.0.1
# idna                      3.6
# imageio                   2.34.0
# importlib-metadata        6.11.0
# importlib-resources       6.1.1
# ipykernel                 6.29.2
# ipython                   8.22.0
# ipywidgets                8.1.2
# isoduration               20.11.0
# itsdangerous              2.1.2
# jedi                      0.19.1
# Jinja2                    3.1.3
# jmespath                  1.0.1
# joblib                    1.3.2
# json5                     0.9.17
# jsonpointer               2.4
# jsonschema                4.21.1
# jsonschema-specifications 2023.12.1
# jupyter                   1.0.0
# jupyter_client            8.6.0
# jupyter-console           6.6.3
# jupyter_core              5.7.1
# jupyter-events            0.9.0
# jupyter-lsp               2.2.2
# jupyter_server            2.12.5
# jupyter_server_terminals  0.5.2
# jupyterlab                4.1.2
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.25.3
# jupyterlab_widgets        3.0.10
# kiwisolver                1.4.5
# krb5                      0.5.1
# llvmlite                  0.42.0
# markdown-it-py            3.0.0
# MarkupSafe                2.1.5
# matplotlib                3.8.3
# matplotlib-inline         0.1.6
# mdurl                     0.1.2
# mistune                   3.0.2
# mpi4py                    3.1.5
# mpmath                    1.3.0
# multiprocess              0.70.16
# munkres                   1.1.4
# nbclient                  0.8.0
# nbconvert                 7.16.1
# nbformat                  5.9.2
# nest_asyncio              1.6.0
# networkx                  3.2.1
# ninja                     1.11.1.1
# notebook                  7.1.0
# notebook_shim             0.2.4
# numba                     0.59.0
# numpy                     1.26.4
# nvgpu                     0.10.0
# nvidia-ml-py              12.535.133
# onnx                      1.13.1
# opencv-python             4.9.0.80
# orjson                    3.10.1
# overrides                 7.7.0
# packaging                 21.3
# pandas                    1.5.3
# pandocfilters             1.5.0
# parso                     0.8.3
# pathos                    0.3.2
# patsy                     0.5.6
# pexpect                   4.9.0
# pickleshare               0.7.5
# pillow                    10.2.0
# pip                       24.0
# pkgutil_resolve_name      1.3.10
# platformdirs              4.2.0
# playwright                1.25.0
# plotly                    5.19.0
# pox                       0.3.4
# ppft                      1.7.6.8
# prometheus_client         0.20.0
# prompt-toolkit            3.0.42
# protobuf                  4.25.3
# psutil                    5.9.8
# ptyprocess                0.7.0
# pure-eval                 0.2.2
# py4j                      0.10.9.5
# pyarrow                   15.0.0
# pyasn1                    0.5.1
# pybind11                  2.11.1
# pybind11-global           2.11.1
# pycparser                 2.21
# pydantic                  2.6.1
# pydantic_core             2.16.2
# pydub                     0.25.1
# pyee                      8.1.0
# pyfunctional              1.4.3
# pygame                    2.5.2
# Pygments                  2.17.2
# pynvml                    11.5.0
# pyparsing                 3.1.1
# PySocks                   1.7.1
# pyspark                   3.3.0
# pyspnego                  0.10.2
# python-dateutil           2.8.2
# python-json-logger        2.0.7
# python-multipart          0.0.9
# pytz                      2024.1
# PyYAML                    6.0.1
# pyzmq                     25.1.2
# qtconsole                 5.5.1
# QtPy                      2.4.1
# referencing               0.33.0
# regex                     2024.4.16
# requests                  2.31.0
# requests-kerberos         0.14.0
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rich                      13.7.1
# rpds-py                   0.18.0
# rsa                       4.7.2
# ruamel.yaml               0.18.6
# ruamel.yaml.clib          0.2.8
# ruff                      0.4.1
# s3fs                      0.4.2
# s3transfer                0.10.0
# safetensors               0.4.3
# sagemaker                 2.215.0
# sagemaker_pyspark         1.4.5
# schema                    0.7.5
# scikit-learn              1.4.1.post1
# scipy                     1.12.0
# seaborn                   0.13.2
# semantic-version          2.10.0
# Send2Trash                1.8.2
# setuptools                69.1.0
# shap                      0.40.0
# shellingham               1.5.4
# six                       1.16.0
# slicer                    0.0.7
# smclarify                 0.5
# smdebug-rulesconfig       1.0.1
# sniffio                   1.3.0
# soupsieve                 2.5
# spaces                    0.26.1
# sparkmagic                0.21.0
# stack-data                0.6.2
# starlette                 0.37.2
# statsmodels               0.14.1
# sympy                     1.12
# tabulate                  0.9.0
# tblib                     2.0.0
# tenacity                  8.2.3
# termcolor                 2.4.0
# terminado                 0.18.0
# threadpoolctl             3.3.0
# tinycss2                  1.2.1
# tokenizers                0.19.1
# tomli                     2.0.1
# tomlkit                   0.12.0
# toolz                     0.12.1
# torch                     2.1.0
# torch-model-archiver      0.7.1b20230208
# torch-workflow-archiver   0.2.11b20231012
# torchaudio                2.1.0
# torchdata                 0.7.0
# torchserve                0.8.2b20230828
# torchtext                 0.16.0
# torchvision               0.16.0
# tornado                   6.4
# tqdm                      4.66.2
# traitlets                 5.14.1
# transformers              4.40.1
# triton                    2.1.0
# typer                     0.12.3
# types-python-dateutil     2.8.19.20240106
# typing_extensions         4.9.0
# typing-utils              0.1.0
# tzdata                    2024.1
# ujson                     5.9.0
# unicodedata2              15.1.0
# uri-template              1.3.0
# urllib3                   2.0.7
# uvicorn                   0.29.0
# wcwidth                   0.2.13
# webcolors                 1.13
# webencodings              0.5.1
# websocket-client          1.7.0
# websockets                10.1
# Werkzeug                  3.0.1
# wheel                     0.42.0
# widgetsnbextension        4.0.10
# xyzservices               2023.10.1
# zipp                      3.17.0

# %%
import torch
torch.cuda.empty_cache()
torch.cuda.synchronize()

# %%
# !pip install Pillow
####!pip install --upgrade gradio_client
# Out:
# Requirement already satisfied: Pillow in /home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/site-packages (10.2.0)

# %%
import os
import subprocess
import spaces
import torch

import gradio as gr

from gradio_client.client import DEFAULT_TEMP_DIR
from playwright.sync_api import sync_playwright
from threading import Thread
from transformers import AutoProcessor, AutoModelForCausalLM, TextIteratorStreamer
from transformers.image_utils import to_numpy_array, PILImageResampling, ChannelDimension
from typing import List
from PIL import Image

from transformers.image_transforms import resize, to_channel_dimension_format


subprocess.run('pip install flash-attn --no-build-isolation', env={'FLASH_ATTENTION_SKIP_CUDA_BUILD': "TRUE"}, shell=True)

DEVICE = torch.device("cuda")
PROCESSOR = AutoProcessor.from_pretrained(
    "HuggingFaceM4/VLM_WebSight_finetuned",
)
MODEL = AutoModelForCausalLM.from_pretrained(
    "HuggingFaceM4/VLM_WebSight_finetuned",
    trust_remote_code=True,
    torch_dtype=torch.bfloat16,
).to(DEVICE)
if MODEL.config.use_resampler:
    image_seq_len = MODEL.config.perceiver_config.resampler_n_latents
else:
    image_seq_len = (
        MODEL.config.vision_config.image_size // MODEL.config.vision_config.patch_size
    ) ** 2
BOS_TOKEN = PROCESSOR.tokenizer.bos_token
BAD_WORDS_IDS = PROCESSOR.tokenizer(["", "<fake_token_around_image>"], add_special_tokens=False).input_ids


## Utils

def convert_to_rgb(image):
    # `image.convert("RGB")` would only work for .jpg images, as it creates a wrong background
    # for transparent images. The call to `alpha_composite` handles this case
    if image.mode == "RGB":
        return image

    image_rgba = image.convert("RGBA")
    background = Image.new("RGBA", image_rgba.size, (255, 255, 255))
    alpha_composite = Image.alpha_composite(background, image_rgba)
    alpha_composite = alpha_composite.convert("RGB")
    return alpha_composite

# The processor is the same as the Idefics processor except for the BICUBIC interpolation inside siglip,
# so this is a hack in order to redefine ONLY the transform method
def custom_transform(x):
    x = convert_to_rgb(x)
    x = to_numpy_array(x)
    x = resize(x, (960, 960), resample=PILImageResampling.BILINEAR)
    x = PROCESSOR.image_processor.rescale(x, scale=1 / 255)
    x = PROCESSOR.image_processor.normalize(
        x,
        mean=PROCESSOR.image_processor.image_mean,
        std=PROCESSOR.image_processor.image_std
    )
    x = to_channel_dimension_format(x, ChannelDimension.FIRST)
    x = torch.tensor(x)
    return x

## End of Utils


IMAGE_GALLERY_PATHS = [
    f"example_images/{ex_image}"
    for ex_image in os.listdir(f"example_images")
]


def install_playwright():
    try:
        subprocess.run(["playwright", "install"], check=True)
        print("Playwright installation successful.")
    except subprocess.CalledProcessError as e:
        print(f"Error during Playwright installation: {e}")

install_playwright()


def add_file_gallery(
    selected_state: gr.SelectData,
    gallery_list: List[str]
):
    return Image.open(gallery_list.root[selected_state.index].image.path)


def render_webpage(
    html_css_code,
):
    with sync_playwright() as p:
        browser = p.chromium.launch(headless=True)
        context = browser.new_context(
            user_agent=(
                "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0"
                " Safari/537.36"
            )
        )
        page = context.new_page()
        page.set_content(html_css_code)
        page.wait_for_load_state("networkidle")
        output_path_screenshot = f"{DEFAULT_TEMP_DIR}/{hash(html_css_code)}.png"
        _ = page.screenshot(path=output_path_screenshot, full_page=True)

        context.close()
        browser.close()

    return Image.open(output_path_screenshot)


@spaces.GPU(duration=180)
def model_inference(
    image,
):
    if image is None:
        raise ValueError("`image` is None. It should be a PIL image.")

    inputs = PROCESSOR.tokenizer(
        f"{BOS_TOKEN}<fake_token_around_image>{'' * image_seq_len}<fake_token_around_image>",
        return_tensors="pt",
        add_special_tokens=False,
    )
    inputs["pixel_values"] = PROCESSOR.image_processor(
        [image],
        transform=custom_transform
    )
    inputs = {
        k: v.to(DEVICE)
        for k, v in inputs.items()
    }

    streamer = TextIteratorStreamer(
        PROCESSOR.tokenizer,
        skip_prompt=True,
    )
    generation_kwargs = dict(
        inputs,
        bad_words_ids=BAD_WORDS_IDS,
        max_length=4096,
        streamer=streamer,
    )
    # Regular generation version
    # generation_kwargs.pop("streamer")
    # generated_ids = MODEL.generate(**generation_kwargs)
    # generated_text = PROCESSOR.batch_decode(
    #     generated_ids,
    #     skip_special_tokens=True
    # )[0]
    # rendered_page = render_webpage(generated_text)
    # return generated_text, rendered_page
    # Token streaming version
    thread = Thread(
        target=MODEL.generate,
        kwargs=generation_kwargs,
    )
    thread.start()
    generated_text = ""
    for new_text in streamer:
        if "</s>" in new_text:
            new_text = new_text.replace("</s>", "")
            rendered_image = render_webpage(generated_text)
        else:
            rendered_image = None
        generated_text += new_text
        yield generated_text, rendered_image


generated_html = gr.Code(
    label="Extracted HTML",
    elem_id="generated_html",
)
rendered_html = gr.Image(
    label="Rendered HTML",
    show_download_button=False,
    show_share_button=False,
)
# rendered_html = gr.HTML(
#     label="Rendered HTML"
# )


css = """
.gradio-container{max-width: 1000px!important}
h1{display: flex;align-items: center;justify-content: center;gap: .25em}
*{transition: width 0.5s ease, flex-grow 0.5s ease}
"""


with gr.Blocks(title="Screenshot to HTML", theme=gr.themes.Base(), css=css) as demo:
    gr.Markdown(
        "Since the model used for this demo *does not generate images*, it is more effective to input standalone website elements or sites with minimal image content."
    )
    with gr.Row(equal_height=True):
        with gr.Column(scale=4, min_width=250) as upload_area:
            imagebox = gr.Image(
                type="pil",
                label="Screenshot to extract",
                visible=True,
                sources=["upload", "clipboard"],
            )
            with gr.Group():
                with gr.Row():
                    submit_btn = gr.Button(
                        value="▶️ Submit", visible=True, min_width=120
                    )
                    clear_btn = gr.ClearButton(
                        [imagebox, generated_html, rendered_html], value="🧹 Clear", min_width=120
                    )
                    regenerate_btn = gr.Button(
                        value="🔄 Regenerate", visible=True, min_width=120
                    )
        with gr.Column(scale=4):
            rendered_html.render()

    with gr.Row():
        generated_html.render()

    with gr.Row():
        template_gallery = gr.Gallery(
            value=IMAGE_GALLERY_PATHS,
            label="Templates Gallery",
            allow_preview=False,
            columns=5,
            elem_id="gallery",
            show_share_button=False,
            height=400,
        )

    gr.on(
        triggers=[
            imagebox.upload,
            submit_btn.click,
            regenerate_btn.click,
        ],
        fn=model_inference,
        inputs=[imagebox],
        outputs=[generated_html, rendered_html],
    )
    regenerate_btn.click(
        fn=model_inference,
        inputs=[imagebox],
        outputs=[generated_html, rendered_html],
    )
    template_gallery.select(
        fn=add_file_gallery,
        inputs=[template_gallery],
        outputs=[imagebox],
    ).success(
        fn=model_inference,
        inputs=[imagebox],
        outputs=[generated_html, rendered_html],
    )
    demo.load()

demo.queue(max_size=40, api_open=False)
demo.launch(max_threads=400)
# Out:
# Collecting flash-attn
#   Downloading https://files.pythonhosted.org/packages/85/52/9834eb88dd8a8be13b5399a32f23a79f0a307d9708f92e2b4778afaae0d4/flash_attn-2.5.6.tar.gz (2.5MB)
#     Complete output from command python setup.py egg_info:
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-install-c1vmbboz/flash-attn/setup.py", line 9, in <module>
#         from packaging.version import parse, Version
#     ModuleNotFoundError: No module named 'packaging'
#
#     ----------------------------------------
# Command "python setup.py egg_info" failed with error code 1 in /tmp/pip-install-c1vmbboz/flash-attn/
# preprocessor_config.json:   0%|          | 0.00/351 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.28k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/61.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/552 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/1.63k [00:00<?, ?B/s]
# configuration_vmistral.py:   0%|          | 0.00/14.8k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/HuggingFaceM4/VLM_WebSight_finetuned:
# - configuration_vmistral.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_vmistral.py:   0%|          | 0.00/81.2k [00:00<?, ?B/s]
# vision.py:   0%|          | 0.00/28.0k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/HuggingFaceM4/VLM_WebSight_finetuned:
# - vision.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/HuggingFaceM4/VLM_WebSight_finetuned:
# - modeling_vmistral.py
# - vision.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# model.safetensors.index.json:   0%|          | 0.00/79.5k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.90G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.69G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# BEWARE: your OS is not officially supported by Playwright; downloading fallback build.
# Downloading Chromium 105.0.5195.19 (playwright build v1019)...
# |                                                                                |   0% of 133.2 Mb
# |■■■■■■■■                                                                        |  10% of 133.2 Mb
# |■■■■■■■■■■■■■■■■                                                                |  20% of 133.2 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■                                                        |  30% of 133.2 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                                |  40% of 133.2 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                        |  50% of 133.2 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                |  60% of 133.2 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                        |  70% of 133.2 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                |  80% of 133.2 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■        |  90% of 133.2 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■| 100% of 133.2 Mb
# Chromium 105.0.5195.19 (playwright build v1019) downloaded to /home/ec2-user/.cache/ms-playwright/chromium-1019
# BEWARE: your OS is not officially supported by Playwright; downloading fallback build.
# Downloading FFMPEG playwright build v1007...
# |                                                                                |   0% of 2.6 Mb
# |■■■■■■■■                                                                        |  10% of 2.6 Mb
# |■■■■■■■■■■■■■■■■                                                                |  20% of 2.6 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■                                                        |  30% of 2.6 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                                |  40% of 2.6 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                        |  50% of 2.6 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                |  60% of 2.6 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                        |  70% of 2.6 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                |  80% of 2.6 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■        |  90% of 2.6 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■| 100% of 2.6 Mb
# FFMPEG playwright build v1007 downloaded to /home/ec2-user/.cache/ms-playwright/ffmpeg-1007
# BEWARE: your OS is not officially supported by Playwright; downloading fallback build.
# Downloading Firefox 103.0 (playwright build v1344)...
# |                                                                                |   0% of 76.3 Mb
# |■■■■■■■■                                                                        |  10% of 76.3 Mb
# |■■■■■■■■■■■■■■■■                                                                |  20% of 76.3 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■                                                        |  30% of 76.3 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                                |  40% of 76.3 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                        |  50% of 76.3 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                |  60% of 76.3 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                        |  70% of 76.3 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                |  80% of 76.3 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■        |  90% of 76.3 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■| 100% of 76.3 Mb
# Firefox 103.0 (playwright build v1344) downloaded to /home/ec2-user/.cache/ms-playwright/firefox-1344
# BEWARE: your OS is not officially supported by Playwright; downloading fallback build.
# Downloading Webkit 16.0 (playwright build v1699)...
# |                                                                                |   0% of 84.7 Mb
# |■■■■■■■■                                                                        |  10% of 84.7 Mb
# |■■■■■■■■■■■■■■■■                                                                |  20% of 84.7 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■                                                        |  30% of 84.7 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                                |  40% of 84.7 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                        |  50% of 84.7 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                |  60% of 84.7 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                        |  70% of 84.7 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                |  80% of 84.7 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■        |  90% of 84.7 Mb
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■| 100% of 84.7 Mb
# Webkit 16.0 (playwright build v1699) downloaded to /home/ec2-user/.cache/ms-playwright/webkit-1699
# Playwright installation successful.
# Running on local URL:  http://127.0.0.1:7860
# Sagemaker notebooks may require sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Running on public URL: https://9c43898c1f71d75183.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://9c43898c1f71d75183.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
